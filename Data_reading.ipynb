# %%
import pandas as pd 
import json

# %%
data = {
    'id':[1,2,3],
    'name' :['Alice','Bob','Charlie'],
    'age' :[25,30,35],
    'city' :['New York', 'London' ,'Paris']
}

ds = pd.DataFrame(data)
ds
# Out:
#    id     name  age      city
# 0   1    Alice   25  New York
# 1   2      Bob   30    London
# 2   3  Charlie   35     Paris

# %%
ds.to_csv('data_csv', index= False )

# %%
ds.to_json('data_json',orient='records', indent=4)
